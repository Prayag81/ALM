# %% [markdown]
# ### Data preprocessing
# # Goal
# 1) Convert the frequency to 16kHz
# 2) convert the chanels to mono
# 3) make the duration to 5 sec
# 4) Trimming the scilence
# 5) nomalize the amptitude
